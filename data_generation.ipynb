# %% [markdown]
# # Events Generation

# %%
import random 
import numpy as np
import pandas as pd
import json
import time

from confluent_kafka import Producer
from confluent_kafka.admin import AdminClient, NewTopic
from loguru import logger
from datetime import timedelta
from faker import Faker

from confluent_kafka import SerializingProducer
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.avro import AvroSerializer
from confluent_kafka.serialization import StringSerializer

# %%
PROD_IDS = [
    "fert_001", "fert_002", "fert_003", "fert_004", "fert_005",
    "seed_001", "seed_002", "seed_003", "seed_004", "seed_005",
    "pest_001", "pest_002", "pest_003", "pest_004", "pest_005",
    "equip_001", "equip_002", "equip_003", "equip_004", "equip_005",
    "supply_001", "supply_002", "supply_003", "supply_004", "supply_005",
    "soil_001", "soil_002", "soil_003", "soil_004", "soil_005"
]

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2025-05-03 14:05:38.219516')

# %%
class EventsGeneration:
    def __init__(self, config_path: str):
        self.config = EventsGeneration.read_config(config_path)
        self.schema_registry_config = {k: self.config.pop(k) for k in ["url", "basic.auth.user.info"] if k in self.config}

    @staticmethod
    def read_config(config_path: str):
        config = {}
        with open(config_path) as fh:
            for line in fh:
                line = line.strip()
                if len(line) != 0 and line[0] != "#":
                    parameter, value = line.strip().split('=', 1)
                    config[parameter] = value.strip()
        return config

    def create_topics(self, topics: list) -> None:
        admin_client = AdminClient(self.config) 
        topic_list = admin_client.list_topics().topics 
        logger.info(f"Available topics in the Kafka cluster: {topic_list}")

        for topic in topics:
            new_topic = NewTopic(topic, num_partitions=3, replication_factor=3)
            fs = admin_client.create_topics([new_topic])

            for topic, f in fs.items(): 
                try: 
                    f.result()
                    logger.info(f"Topic {topic} created") 
                except Exception as ex: 
                    logger.info(f"Error while creeating topic {topic}: {ex}")

    @staticmethod
    def iot_event_generation(previous_timestamp):
        key = f"sensor_{random.randint(1,20):03}"
        temp = float(np.random.normal(25, 15, 1).clip(-10, 45).round(1)[0]) if random.random()<0.8 else np.nan
        hum = float(np.random.normal(45, 20, 1).clip(0, 100).round(1)[0]) if random.random()<0.8 else np.nan
        quality = float(np.random.normal(50, 35, 1).clip(0, 100).round(1)[0]) if random.random()<0.8 else np.nan
        value = {
            "timestamp": previous_timestamp + timedelta(seconds=random.randint(10, 200)),
            "soil_temperature": temp,
            "soil_humidity": hum,
            "soil_quality": quality,
        }
        return key, value

    @staticmethod
    def client_data_event_generation(previous_timestamp, faker_instance):
        key = f"user_{random.randint(1, 5000):04}"
        value = {
            "timestamp": (previous_timestamp + timedelta(seconds=random.randint(10, 200))).isoformat(),
            "full_name": faker_instance.unique.name(),
            "email": faker_instance.unique.email(),
            "age": random.randint(21, 70),
            "clicked_ads": random.randint(1,20),
            "wishlist_items": np.random.choice(PROD_IDS, random.randint(1, 10)).tolist(),
            "engagement_score": round(random.random(), 3),
        }
        return key, value
    
    def produce_client_events(self, amount_events):
        producer = Producer(self.config) 
        fake = Faker()
        current_timestamp = pd.Timestamp.now()
        for i in range(amount_events):
            key,value = EventsGeneration.client_data_event_generation(current_timestamp, fake)
            current_timestamp = pd.Timestamp(value.get("timestamp"))
            producer.produce(topic="topic_client_data", key=key, value=json.dumps(value))
            producer.flush()
            logger.info(f"Message {i+1} sent")
            sleep_time = (
                random.randint(0, int(1 * 10000)) / 10000
            )
            time.sleep(sleep_time)

    def produce_iot_events(self, amount_events):
        value_schema_str = """
        {
            "namespace": "sensors.iot",
            "type": "record",
            "name": "Telemetry",
            "fields" : [
                {"name": "timestamp", "type": {"type": "long", "logicalType": "timestamp-millis"}},
                {"name": "soil_temperature", "type" : "double"},
                {"name": "soil_humidity", "type" : "double"},
                {"name": "soil_quality", "type" : "double"}
            ]
        }
        """

        schema_registry_client = SchemaRegistryClient(self.schema_registry_config)

        def telemetry_to_dict(obj, ctx):
            return obj  # we already provide a dict

        value_serializer = AvroSerializer(
            schema_str=value_schema_str,
            schema_registry_client=schema_registry_client,
            to_dict=telemetry_to_dict
        )

        serializers_config = {
            "key.serializer": StringSerializer("utf_8"),
            "value.serializer": value_serializer
        }

        avro_config = {**self.config, **serializers_config}
        producer = SerializingProducer(avro_config)
        current_timestamp = pd.Timestamp.now()
        for i in range(amount_events):
            key, value = EventsGeneration.iot_event_generation(current_timestamp)
            current_timestamp = value.get("timestamp")
            producer.produce(topic="topic_iot_sensors", key=key, value=value)
            producer.flush()
            logger.info(f"Message {i+1} sent")
            sleep_time = (
                random.randint(0, int(1 * 10000)) / 10000
            )
            time.sleep(sleep_time)

# %%
topics_list = ["topic_client_data", "topic_iot_sensors"]
config_path = "./config/confluent_kafka/client_properties"
generator = EventsGeneration(config_path)

# %%
generator.schema_registry_config
# Out:
# {'url': 'https://psrc-e0919.us-east-2.aws.confluent.cloud',
#  'basic.auth.user.info': '3V6ZA52AX2PJTOQX:f22gMhO6kWGSCk3GKq84R2rJ9fM3zoVdVTmt1nY5pPWkupMgq5S3G3zliVBaPb0v'}

# %% [markdown]
# # Create Topics **(If not exists)**

# %%
generator.create_topics(topics_list)
# Out:
# %4|1746281828.988|CONFWARN|ccloud-python-client-758566b2-581f-4b70-97c0-96c6f69c3fb4#producer-1| [thrd:app]: Configuration property session.timeout.ms is a consumer property and will be ignored by this producer instance
# 2025-05-03 16:17:09.916 | INFO     | __main__:create_topics:20 - Available topics in the Kafka cluster: {}
# %6|1746281830.856|GETSUBSCRIPTIONS|ccloud-python-client-758566b2-581f-4b70-97c0-96c6f69c3fb4#producer-1| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to b0KbJ/blSb6E2hYpJL8XdQ
# 2025-05-03 16:17:10.920 | INFO     | __main__:create_topics:29 - Topic topic_client_data created
# 2025-05-03 16:17:11.107 | INFO     | __main__:create_topics:29 - Topic topic_iot_sensors created

# %% [markdown]
# # Produce client data events

# %%
generator.produce_client_events(100)
# Out:
# %4|1746452512.936|CONFWARN|ccloud-python-client-758566b2-581f-4b70-97c0-96c6f69c3fb4#producer-3| [thrd:app]: Configuration property session.timeout.ms is a consumer property and will be ignored by this producer instance
# 2025-05-05 15:41:54.729 | INFO     | __main__:produce_client_events:70 - Message 1 sent
# %6|1746452514.729|GETSUBSCRIPTIONS|ccloud-python-client-758566b2-581f-4b70-97c0-96c6f69c3fb4#producer-3| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to zRfS0BOLTHm1F45KJ0go9Q
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 generator.produce_client_events(100)
#
# Cell In[9], line 69, in EventsGeneration.produce_client_events(self, amount_events)
#      67 current_timestamp = pd.Timestamp(value.get("timestamp"))
#      68 producer.produce(topic="topic_client_data", key=key, value=json.dumps(value))
# ---> 69 producer.flush()
#      70 logger.info(f"Message {i+1} sent")
#      71 sleep_time = (
#      72     random.randint(0, int(1 * 10000)) / 10000
#      73 )
#
# KeyboardInterrupt:

# %% [markdown]
# # Produce IOT events

# %%
generator.produce_iot_events(200)
# Out:
# %4|1746454601.201|CONFWARN|ccloud-python-client-758566b2-581f-4b70-97c0-96c6f69c3fb4#producer-6| [thrd:app]: Configuration property session.timeout.ms is a consumer property and will be ignored by this producer instance
# 2025-05-05 16:16:43.084 | INFO     | __main__:produce_iot_events:115 - Message 1 sent
# %6|1746454603.084|GETSUBSCRIPTIONS|ccloud-python-client-758566b2-581f-4b70-97c0-96c6f69c3fb4#producer-6| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to 6EQyTxEkS8u45ganra6rQA
# 2025-05-05 16:16:44.060 | INFO     | __main__:produce_iot_events:115 - Message 2 sent
# 2025-05-05 16:16:44.863 | INFO     | __main__:produce_iot_events:115 - Message 3 sent
# 2025-05-05 16:16:46.857 | INFO     | __main__:produce_iot_events:115 - Message 4 sent
# 2025-05-05 16:16:47.376 | INFO     | __main__:produce_iot_events:115 - Message 5 sent
# 2025-05-05 16:16:48.544 | INFO     | __main__:produce_iot_events:115 - Message 6 sent
# 2025-05-05 16:16:49.399 | INFO     | __main__:produce_iot_events:115 - Message 7 sent
# 2025-05-05 16:16:50.005 | INFO     | __main__:produce_iot_events:115 - Message 8 sent
# 2025-05-05 16:16:50.944 | INFO     | __main__:produce_iot_events:115 - Message 9 sent
# 2025-05-05 16:16:51.301 | INFO     | __main__:produce_iot_events:115 - Message 10 sent
# 2025-05-05 16:16:52.207 | INFO     | __main__:produce_iot_events:115 - Message 11 sent
# 2025-05-05 16:16:52.624 | INFO     | __main__:produce_iot_events:115 - Message 12 sent
# 2025-05-05 16:16:54.258 | INFO     | __main__:produce_iot_events:115 - Message 13 sent
# 2025-05-05 16:16:55.359 | INFO     | __main__:produce_iot_events:115 - Message 14 sent
# 2025-05-05 16:16:56.403 | INFO     | __main__:produce_iot_events:115 - Message 15 sent
# 2025-05-05 16:16:56.623 | INFO     | __main__:produce_iot_events:115 - Message 16 sent
# 2025-05-05 16:16:57.450 | INFO     | __main__:produce_iot_events:115 - Message 17 sent
# 2025-05-05 16:16:58.396 | INFO     | __main__:produce_iot_events:115 - Message 18 sent
# 2025-05-05 16:16:59.026 | INFO     | __main__:produce_iot_events:115 - Message 19 sent
# 2025-05-05 16:16:59.133 | INFO     | __main__:produce_iot_events:115 - Message 20 sent
# 2025-05-05 16:17:00.223 | INFO     | __main__:produce_iot_events:115 - Message 21 sent
# 2025-05-05 16:17:00.760 | INFO     | __main__:produce_iot_events:115 - Message 22 sent
# 2025-05-05 16:17:01.821 | INFO     | __main__:produce_iot_events:115 - Message 23 sent
# 2025-05-05 16:17:02.168 | INFO     | __main__:produce_iot_events:115 - Message 24 sent
# 2025-05-05 16:17:02.712 | INFO     | __main__:produce_iot_events:115 - Message 25 sent
# 2025-05-05 16:17:03.773 | INFO     | __main__:produce_iot_events:115 - Message 26 sent
# 2025-05-05 16:17:04.311 | INFO     | __main__:produce_iot_events:115 - Message 27 sent
# 2025-05-05 16:17:04.872 | INFO     | __main__:produce_iot_events:115 - Message 28 sent
# 2025-05-05 16:17:05.316 | INFO     | __main__:produce_iot_events:115 - Message 29 sent
# 2025-05-05 16:17:05.860 | INFO     | __main__:produce_iot_events:115 - Message 30 sent
# 2025-05-05 16:17:06.910 | INFO     | __main__:produce_iot_events:115 - Message 31 sent
# 2025-05-05 16:17:07.936 | INFO     | __main__:produce_iot_events:115 - Message 32 sent
# 2025-05-05 16:17:08.093 | INFO     | __main__:produce_iot_events:115 - Message 33 sent
# 2025-05-05 16:17:08.454 | INFO     | __main__:produce_iot_events:115 - Message 34 sent
# 2025-05-05 16:17:09.094 | INFO     | __main__:produce_iot_events:115 - Message 35 sent
# 2025-05-05 16:17:09.833 | INFO     | __main__:produce_iot_events:115 - Message 36 sent
# 2025-05-05 16:17:10.164 | INFO     | __main__:produce_iot_events:115 - Message 37 sent
# 2025-05-05 16:17:10.586 | INFO     | __main__:produce_iot_events:115 - Message 38 sent
# 2025-05-05 16:17:11.500 | INFO     | __main__:produce_iot_events:115 - Message 39 sent
# 2025-05-05 16:17:11.866 | INFO     | __main__:produce_iot_events:115 - Message 40 sent
# 2025-05-05 16:17:12.290 | INFO     | __main__:produce_iot_events:115 - Message 41 sent
# 2025-05-05 16:17:13.203 | INFO     | __main__:produce_iot_events:115 - Message 42 sent
# 2025-05-05 16:17:13.866 | INFO     | __main__:produce_iot_events:115 - Message 43 sent
# 2025-05-05 16:17:14.451 | INFO     | __main__:produce_iot_events:115 - Message 44 sent
# 2025-05-05 16:17:14.647 | INFO     | __main__:produce_iot_events:115 - Message 45 sent
# 2025-05-05 16:17:15.433 | INFO     | __main__:produce_iot_events:115 - Message 46 sent
# 2025-05-05 16:17:16.326 | INFO     | __main__:produce_iot_events:115 - Message 47 sent
# 2025-05-05 16:17:17.375 | INFO     | __main__:produce_iot_events:115 - Message 48 sent
# 2025-05-05 16:17:18.223 | INFO     | __main__:produce_iot_events:115 - Message 49 sent
# 2025-05-05 16:17:18.954 | INFO     | __main__:produce_iot_events:115 - Message 50 sent
# 2025-05-05 16:17:20.052 | INFO     | __main__:produce_iot_events:115 - Message 51 sent
# 2025-05-05 16:17:20.614 | INFO     | __main__:produce_iot_events:115 - Message 52 sent
# 2025-05-05 16:17:20.938 | INFO     | __main__:produce_iot_events:115 - Message 53 sent
# 2025-05-05 16:17:21.570 | INFO     | __main__:produce_iot_events:115 - Message 54 sent
# 2025-05-05 16:17:22.185 | INFO     | __main__:produce_iot_events:115 - Message 55 sent
# 2025-05-05 16:17:23.040 | INFO     | __main__:produce_iot_events:115 - Message 56 sent
# 2025-05-05 16:17:24.163 | INFO     | __main__:produce_iot_events:115 - Message 57 sent
# 2025-05-05 16:17:24.723 | INFO     | __main__:produce_iot_events:115 - Message 58 sent
# 2025-05-05 16:17:25.336 | INFO     | __main__:produce_iot_events:115 - Message 59 sent
# 2025-05-05 16:17:25.474 | INFO     | __main__:produce_iot_events:115 - Message 60 sent
# 2025-05-05 16:17:26.182 | INFO     | __main__:produce_iot_events:115 - Message 61 sent
# 2025-05-05 16:17:27.332 | INFO     | __main__:produce_iot_events:115 - Message 62 sent
# 2025-05-05 16:17:27.774 | INFO     | __main__:produce_iot_events:115 - Message 63 sent
# 2025-05-05 16:17:28.500 | INFO     | __main__:produce_iot_events:115 - Message 64 sent
# 2025-05-05 16:17:29.509 | INFO     | __main__:produce_iot_events:115 - Message 65 sent
# 2025-05-05 16:17:29.857 | INFO     | __main__:produce_iot_events:115 - Message 66 sent
# 2025-05-05 16:17:30.652 | INFO     | __main__:produce_iot_events:115 - Message 67 sent
# 2025-05-05 16:17:30.905 | INFO     | __main__:produce_iot_events:115 - Message 68 sent
# 2025-05-05 16:17:31.216 | INFO     | __main__:produce_iot_events:115 - Message 69 sent
# 2025-05-05 16:17:32.266 | INFO     | __main__:produce_iot_events:115 - Message 70 sent
# 2025-05-05 16:17:33.129 | INFO     | __main__:produce_iot_events:115 - Message 71 sent
# 2025-05-05 16:17:33.842 | INFO     | __main__:produce_iot_events:115 - Message 72 sent
# 2025-05-05 16:17:34.395 | INFO     | __main__:produce_iot_events:115 - Message 73 sent
# 2025-05-05 16:17:35.198 | INFO     | __main__:produce_iot_events:115 - Message 74 sent
# 2025-05-05 16:17:36.148 | INFO     | __main__:produce_iot_events:115 - Message 75 sent
# 2025-05-05 16:17:36.667 | INFO     | __main__:produce_iot_events:115 - Message 76 sent
# 2025-05-05 16:17:37.001 | INFO     | __main__:produce_iot_events:115 - Message 77 sent
# 2025-05-05 16:17:37.390 | INFO     | __main__:produce_iot_events:115 - Message 78 sent
# 2025-05-05 16:17:38.154 | INFO     | __main__:produce_iot_events:115 - Message 79 sent
# 2025-05-05 16:17:39.084 | INFO     | __main__:produce_iot_events:115 - Message 80 sent
# 2025-05-05 16:17:39.572 | INFO     | __main__:produce_iot_events:115 - Message 81 sent
# 2025-05-05 16:17:40.128 | INFO     | __main__:produce_iot_events:115 - Message 82 sent
# 2025-05-05 16:17:41.164 | INFO     | __main__:produce_iot_events:115 - Message 83 sent
# 2025-05-05 16:17:42.115 | INFO     | __main__:produce_iot_events:115 - Message 84 sent
# 2025-05-05 16:17:42.597 | INFO     | __main__:produce_iot_events:115 - Message 85 sent
# 2025-05-05 16:17:42.958 | INFO     | __main__:produce_iot_events:115 - Message 86 sent
# 2025-05-05 16:17:43.331 | INFO     | __main__:produce_iot_events:115 - Message 87 sent
# 2025-05-05 16:17:44.012 | INFO     | __main__:produce_iot_events:115 - Message 88 sent
# 2025-05-05 16:17:44.688 | INFO     | __main__:produce_iot_events:115 - Message 89 sent
# 2025-05-05 16:17:45.318 | INFO     | __main__:produce_iot_events:115 - Message 90 sent
# 2025-05-05 16:17:46.274 | INFO     | __main__:produce_iot_events:115 - Message 91 sent
# 2025-05-05 16:17:46.876 | INFO     | __main__:produce_iot_events:115 - Message 92 sent
# 2025-05-05 16:17:47.683 | INFO     | __main__:produce_iot_events:115 - Message 93 sent
# 2025-05-05 16:17:47.974 | INFO     | __main__:produce_iot_events:115 - Message 94 sent
# 2025-05-05 16:17:48.300 | INFO     | __main__:produce_iot_events:115 - Message 95 sent
# 2025-05-05 16:17:48.898 | INFO     | __main__:produce_iot_events:115 - Message 96 sent
# 2025-05-05 16:17:49.358 | INFO     | __main__:produce_iot_events:115 - Message 97 sent
# 2025-05-05 16:17:49.582 | INFO     | __main__:produce_iot_events:115 - Message 98 sent
# 2025-05-05 16:17:50.407 | INFO     | __main__:produce_iot_events:115 - Message 99 sent
# 2025-05-05 16:17:51.150 | INFO     | __main__:produce_iot_events:115 - Message 100 sent
# 2025-05-05 16:17:51.978 | INFO     | __main__:produce_iot_events:115 - Message 101 sent
# 2025-05-05 16:17:52.613 | INFO     | __main__:produce_iot_events:115 - Message 102 sent
# 2025-05-05 16:17:53.319 | INFO     | __main__:produce_iot_events:115 - Message 103 sent
# 2025-05-05 16:17:53.808 | INFO     | __main__:produce_iot_events:115 - Message 104 sent
# 2025-05-05 16:17:54.602 | INFO     | __main__:produce_iot_events:115 - Message 105 sent
# 2025-05-05 16:17:54.754 | INFO     | __main__:produce_iot_events:115 - Message 106 sent
# 2025-05-05 16:17:55.302 | INFO     | __main__:produce_iot_events:115 - Message 107 sent
# 2025-05-05 16:17:55.640 | INFO     | __main__:produce_iot_events:115 - Message 108 sent
# 2025-05-05 16:17:55.872 | INFO     | __main__:produce_iot_events:115 - Message 109 sent
# 2025-05-05 16:17:56.724 | INFO     | __main__:produce_iot_events:115 - Message 110 sent
# 2025-05-05 16:17:57.224 | INFO     | __main__:produce_iot_events:115 - Message 111 sent
# 2025-05-05 16:17:58.268 | INFO     | __main__:produce_iot_events:115 - Message 112 sent
# 2025-05-05 16:17:59.216 | INFO     | __main__:produce_iot_events:115 - Message 113 sent
# 2025-05-05 16:18:00.066 | INFO     | __main__:produce_iot_events:115 - Message 114 sent
# 2025-05-05 16:18:00.372 | INFO     | __main__:produce_iot_events:115 - Message 115 sent
# 2025-05-05 16:18:00.942 | INFO     | __main__:produce_iot_events:115 - Message 116 sent
# 2025-05-05 16:18:01.615 | INFO     | __main__:produce_iot_events:115 - Message 117 sent
# 2025-05-05 16:18:01.936 | INFO     | __main__:produce_iot_events:115 - Message 118 sent
# 2025-05-05 16:18:03.036 | INFO     | __main__:produce_iot_events:115 - Message 119 sent
# 2025-05-05 16:18:04.094 | INFO     | __main__:produce_iot_events:115 - Message 120 sent
# 2025-05-05 16:18:04.564 | INFO     | __main__:produce_iot_events:115 - Message 121 sent
# 2025-05-05 16:18:05.188 | INFO     | __main__:produce_iot_events:115 - Message 122 sent
# 2025-05-05 16:18:05.628 | INFO     | __main__:produce_iot_events:115 - Message 123 sent
# 2025-05-05 16:18:06.657 | INFO     | __main__:produce_iot_events:115 - Message 124 sent
# 2025-05-05 16:18:07.251 | INFO     | __main__:produce_iot_events:115 - Message 125 sent
# 2025-05-05 16:18:07.973 | INFO     | __main__:produce_iot_events:115 - Message 126 sent
# 2025-05-05 16:18:08.225 | INFO     | __main__:produce_iot_events:115 - Message 127 sent
# 2025-05-05 16:18:09.551 | INFO     | __main__:produce_iot_events:115 - Message 128 sent
# 2025-05-05 16:18:09.986 | INFO     | __main__:produce_iot_events:115 - Message 129 sent
# 2025-05-05 16:18:10.899 | INFO     | __main__:produce_iot_events:115 - Message 130 sent
# 2025-05-05 16:18:11.902 | INFO     | __main__:produce_iot_events:115 - Message 131 sent
# 2025-05-05 16:18:12.093 | INFO     | __main__:produce_iot_events:115 - Message 132 sent
# 2025-05-05 16:18:13.112 | INFO     | __main__:produce_iot_events:115 - Message 133 sent
# 2025-05-05 16:18:13.728 | INFO     | __main__:produce_iot_events:115 - Message 134 sent
# 2025-05-05 16:18:14.418 | INFO     | __main__:produce_iot_events:115 - Message 135 sent
# 2025-05-05 16:18:14.693 | INFO     | __main__:produce_iot_events:115 - Message 136 sent
# 2025-05-05 16:18:15.138 | INFO     | __main__:produce_iot_events:115 - Message 137 sent
# 2025-05-05 16:18:15.693 | INFO     | __main__:produce_iot_events:115 - Message 138 sent
# 2025-05-05 16:18:16.406 | INFO     | __main__:produce_iot_events:115 - Message 139 sent
# 2025-05-05 16:18:17.189 | INFO     | __main__:produce_iot_events:115 - Message 140 sent
# 2025-05-05 16:18:17.714 | INFO     | __main__:produce_iot_events:115 - Message 141 sent
# 2025-05-05 16:18:18.796 | INFO     | __main__:produce_iot_events:115 - Message 142 sent
# 2025-05-05 16:18:19.399 | INFO     | __main__:produce_iot_events:115 - Message 143 sent
# 2025-05-05 16:18:19.765 | INFO     | __main__:produce_iot_events:115 - Message 144 sent
# 2025-05-05 16:18:20.816 | INFO     | __main__:produce_iot_events:115 - Message 145 sent
# 2025-05-05 16:18:20.986 | INFO     | __main__:produce_iot_events:115 - Message 146 sent
# 2025-05-05 16:18:22.027 | INFO     | __main__:produce_iot_events:115 - Message 147 sent
# 2025-05-05 16:18:23.032 | INFO     | __main__:produce_iot_events:115 - Message 148 sent
# 2025-05-05 16:18:23.205 | INFO     | __main__:produce_iot_events:115 - Message 149 sent
# 2025-05-05 16:18:23.484 | INFO     | __main__:produce_iot_events:115 - Message 150 sent
# 2025-05-05 16:18:24.613 | INFO     | __main__:produce_iot_events:115 - Message 151 sent
# 2025-05-05 16:18:25.214 | INFO     | __main__:produce_iot_events:115 - Message 152 sent
# 2025-05-05 16:18:25.758 | INFO     | __main__:produce_iot_events:115 - Message 153 sent
# 2025-05-05 16:18:26.775 | INFO     | __main__:produce_iot_events:115 - Message 154 sent
# 2025-05-05 16:18:27.355 | INFO     | __main__:produce_iot_events:115 - Message 155 sent
# 2025-05-05 16:18:28.303 | INFO     | __main__:produce_iot_events:115 - Message 156 sent
# 2025-05-05 16:18:28.605 | INFO     | __main__:produce_iot_events:115 - Message 157 sent
# 2025-05-05 16:18:29.738 | INFO     | __main__:produce_iot_events:115 - Message 158 sent
# 2025-05-05 16:18:30.783 | INFO     | __main__:produce_iot_events:115 - Message 159 sent
# 2025-05-05 16:18:31.416 | INFO     | __main__:produce_iot_events:115 - Message 160 sent
# 2025-05-05 16:18:32.247 | INFO     | __main__:produce_iot_events:115 - Message 161 sent
# 2025-05-05 16:18:32.933 | INFO     | __main__:produce_iot_events:115 - Message 162 sent
# 2025-05-05 16:18:33.396 | INFO     | __main__:produce_iot_events:115 - Message 163 sent
# 2025-05-05 16:18:34.187 | INFO     | __main__:produce_iot_events:115 - Message 164 sent
# 2025-05-05 16:18:34.874 | INFO     | __main__:produce_iot_events:115 - Message 165 sent
# 2025-05-05 16:18:35.205 | INFO     | __main__:produce_iot_events:115 - Message 166 sent
# 2025-05-05 16:18:36.229 | INFO     | __main__:produce_iot_events:115 - Message 167 sent
# 2025-05-05 16:18:36.672 | INFO     | __main__:produce_iot_events:115 - Message 168 sent
# 2025-05-05 16:18:36.976 | INFO     | __main__:produce_iot_events:115 - Message 169 sent
# 2025-05-05 16:18:37.592 | INFO     | __main__:produce_iot_events:115 - Message 170 sent
# 2025-05-05 16:18:37.795 | INFO     | __main__:produce_iot_events:115 - Message 171 sent
# 2025-05-05 16:18:38.122 | INFO     | __main__:produce_iot_events:115 - Message 172 sent
# 2025-05-05 16:18:38.897 | INFO     | __main__:produce_iot_events:115 - Message 173 sent
# 2025-05-05 16:18:39.496 | INFO     | __main__:produce_iot_events:115 - Message 174 sent
# 2025-05-05 16:18:40.364 | INFO     | __main__:produce_iot_events:115 - Message 175 sent
# 2025-05-05 16:18:41.364 | INFO     | __main__:produce_iot_events:115 - Message 176 sent
# 2025-05-05 16:18:41.863 | INFO     | __main__:produce_iot_events:115 - Message 177 sent
# 2025-05-05 16:18:42.853 | INFO     | __main__:produce_iot_events:115 - Message 178 sent
# 2025-05-05 16:18:43.785 | INFO     | __main__:produce_iot_events:115 - Message 179 sent
# 2025-05-05 16:18:44.732 | INFO     | __main__:produce_iot_events:115 - Message 180 sent
# 2025-05-05 16:18:44.963 | INFO     | __main__:produce_iot_events:115 - Message 181 sent
# 2025-05-05 16:18:45.143 | INFO     | __main__:produce_iot_events:115 - Message 182 sent
# 2025-05-05 16:18:45.554 | INFO     | __main__:produce_iot_events:115 - Message 183 sent
# 2025-05-05 16:18:46.090 | INFO     | __main__:produce_iot_events:115 - Message 184 sent
# 2025-05-05 16:18:47.196 | INFO     | __main__:produce_iot_events:115 - Message 185 sent
# 2025-05-05 16:18:47.459 | INFO     | __main__:produce_iot_events:115 - Message 186 sent
# 2025-05-05 16:18:48.099 | INFO     | __main__:produce_iot_events:115 - Message 187 sent
# 2025-05-05 16:18:49.027 | INFO     | __main__:produce_iot_events:115 - Message 188 sent
# 2025-05-05 16:18:49.653 | INFO     | __main__:produce_iot_events:115 - Message 189 sent
# 2025-05-05 16:18:49.881 | INFO     | __main__:produce_iot_events:115 - Message 190 sent
# 2025-05-05 16:18:50.708 | INFO     | __main__:produce_iot_events:115 - Message 191 sent
# 2025-05-05 16:18:51.317 | INFO     | __main__:produce_iot_events:115 - Message 192 sent
# 2025-05-05 16:18:52.274 | INFO     | __main__:produce_iot_events:115 - Message 193 sent
# 2025-05-05 16:18:52.596 | INFO     | __main__:produce_iot_events:115 - Message 194 sent
# 2025-05-05 16:18:52.949 | INFO     | __main__:produce_iot_events:115 - Message 195 sent
# 2025-05-05 16:18:53.401 | INFO     | __main__:produce_iot_events:115 - Message 196 sent
# 2025-05-05 16:18:53.851 | INFO     | __main__:produce_iot_events:115 - Message 197 sent
# 2025-05-05 16:18:54.797 | INFO     | __main__:produce_iot_events:115 - Message 198 sent
# 2025-05-05 16:18:55.184 | INFO     | __main__:produce_iot_events:115 - Message 199 sent
# 2025-05-05 16:18:55.420 | INFO     | __main__:produce_iot_events:115 - Message 200 sent
