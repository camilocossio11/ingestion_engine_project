# %% [markdown]
# # Events Generation Notebook.

# %%
import random 
import numpy as np
import pandas as pd
import json
import time

from confluent_kafka import Producer
from confluent_kafka.admin import AdminClient, NewTopic
from loguru import logger
from datetime import timedelta
from faker import Faker

from confluent_kafka import SerializingProducer
from confluent_kafka.schema_registry import SchemaRegistryClient
from confluent_kafka.schema_registry.avro import AvroSerializer
from confluent_kafka.serialization import StringSerializer

PROD_IDS = [
    "fert_001", "fert_002", "fert_003", "fert_004", "fert_005",
    "seed_001", "seed_002", "seed_003", "seed_004", "seed_005",
    "pest_001", "pest_002", "pest_003", "pest_004", "pest_005",
    "equip_001", "equip_002", "equip_003", "equip_004", "equip_005",
    "supply_001", "supply_002", "supply_003", "supply_004", "supply_005",
    "soil_001", "soil_002", "soil_003", "soil_004", "soil_005"
]

class EventsGeneration:
    def __init__(self, config_path: str):
        self.config = EventsGeneration.read_config(config_path)
        self.schema_registry_config = {k: self.config.pop(k) for k in ["url", "basic.auth.user.info"] if k in self.config}

    @staticmethod
    def read_config(config_path: str):
        config = {}
        with open(config_path) as fh:
            for line in fh:
                line = line.strip()
                if len(line) != 0 and line[0] != "#":
                    parameter, value = line.strip().split('=', 1)
                    config[parameter] = value.strip()
        return config

    def create_topics(self, topics: list) -> None:
        admin_client = AdminClient(self.config) 
        topic_list = admin_client.list_topics().topics 
        logger.info(f"Available topics in the Kafka cluster: {topic_list}")

        for topic in topics:
            new_topic = NewTopic(topic, num_partitions=3, replication_factor=3)
            fs = admin_client.create_topics([new_topic])

            for topic, f in fs.items(): 
                try: 
                    f.result()
                    logger.info(f"Topic {topic} created") 
                except Exception as ex: 
                    logger.info(f"Error while creeating topic {topic}: {ex}")

    @staticmethod
    def iot_event_generation(previous_timestamp):
        key = f"sensor_{random.randint(1,20):03}"
        temp = float(np.random.normal(25, 15, 1).clip(-10, 45).round(1)[0]) if random.random()<0.8 else np.nan
        hum = float(np.random.normal(45, 20, 1).clip(0, 100).round(1)[0]) if random.random()<0.8 else np.nan
        quality = float(np.random.normal(50, 35, 1).clip(0, 100).round(1)[0]) if random.random()<0.8 else np.nan
        value = {
            "timestamp": previous_timestamp + timedelta(seconds=random.randint(10, 200)),
            "soil_temperature": temp,
            "soil_humidity": hum,
            "soil_quality": quality,
        }
        return key, value

    @staticmethod
    def client_data_event_generation(previous_timestamp, faker_instance):
        key = f"user_{random.randint(1, 5000):04}"
        value = {
            "timestamp": (previous_timestamp + timedelta(seconds=random.randint(10, 200))).isoformat(),
            "full_name": faker_instance.unique.name(),
            "email": faker_instance.unique.email(),
            "age": random.randint(21, 70),
            "clicked_ads": random.randint(1,20),
            "wishlist_items": np.random.choice(PROD_IDS, random.randint(1, 10)).tolist(),
            "engagement_score": round(random.random(), 3),
        }
        return key, value
    
    def produce_client_events(self, amount_events):
        producer = Producer(self.config) 
        fake = Faker()
        current_timestamp = pd.Timestamp.now()
        for i in range(amount_events):
            key,value = EventsGeneration.client_data_event_generation(current_timestamp, fake)
            current_timestamp = pd.Timestamp(value.get("timestamp"))
            producer.produce(topic="topic_client_data", key=key, value=json.dumps(value))
            producer.flush()
            logger.info(f"Message {i+1} sent")
            sleep_time = (
                random.randint(0, int(1 * 10000)) / 10000
            )
            time.sleep(sleep_time)

    def produce_iot_events(self, amount_events):
        value_schema_str = """
        {
            "namespace": "sensors.iot",
            "type": "record",
            "name": "Telemetry",
            "fields" : [
                {"name": "timestamp", "type": {"type": "long", "logicalType": "timestamp-millis"}},
                {"name": "soil_temperature", "type" : "double"},
                {"name": "soil_humidity", "type" : "double"},
                {"name": "soil_quality", "type" : "double"}
            ]
        }
        """

        schema_registry_client = SchemaRegistryClient(self.schema_registry_config)

        def telemetry_to_dict(obj, ctx):
            return obj  # we already provide a dict

        value_serializer = AvroSerializer(
            schema_str=value_schema_str,
            schema_registry_client=schema_registry_client,
            to_dict=telemetry_to_dict
        )

        serializers_config = {
            "key.serializer": StringSerializer("utf_8"),
            "value.serializer": value_serializer
        }

        avro_config = {**self.config, **serializers_config}
        producer = SerializingProducer(avro_config)
        current_timestamp = pd.Timestamp.now()
        for i in range(amount_events):
            key, value = EventsGeneration.iot_event_generation(current_timestamp)
            current_timestamp = value.get("timestamp")
            producer.produce(topic="topic_iot_sensors", key=key, value=value)
            producer.flush()
            logger.info(f"Message {i+1} sent")
            sleep_time = (
                random.randint(0, int(1 * 10000)) / 10000
            )
            time.sleep(sleep_time)

topics_list = ["topic_client_data", "topic_iot_sensors"]
config_path = "./config/confluent_kafka/client_properties"
generator = EventsGeneration(config_path)

# %%
generator.schema_registry_config
# Out:
# {'url': 'https://psrc-e0919.us-east-2.aws.confluent.cloud',
#  'basic.auth.user.info': 'YBKO32M7DFEWAQMW:MqK2SrKjWTUUrjjAIbhuSKHal0zsxuvhM0FJ46Ysxp7PsQ1F8LRNMZkRQ78m2O1D'}

# %% [markdown]
# # Create Topics **(If not exists)**

# %%
generator.create_topics(topics_list)
# Out:
# %4|1746723591.636|CONFWARN|ccloud-python-client-364962d7-f8b2-4e17-afa9-91c51a1de59c#producer-2| [thrd:app]: Configuration property session.timeout.ms is a consumer property and will be ignored by this producer instance
# 2025-05-08 18:59:52.633 | INFO     | __main__:create_topics:46 - Available topics in the Kafka cluster: {'topic_client_data': TopicMetadata(topic_client_data, 3 partitions), 'topic_iot_sensors': TopicMetadata(topic_iot_sensors, 3 partitions), 'topic_0': TopicMetadata(topic_0, 6 partitions)}
# %6|1746723593.623|GETSUBSCRIPTIONS|ccloud-python-client-364962d7-f8b2-4e17-afa9-91c51a1de59c#producer-2| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to ome/fYyoSw6oWQEf98UQSA
# 2025-05-08 18:59:53.624 | INFO     | __main__:create_topics:57 - Error while creeating topic topic_client_data: KafkaError{code=TOPIC_ALREADY_EXISTS,val=36,str="Topic 'topic_client_data' already exists."}
# 2025-05-08 18:59:54.513 | INFO     | __main__:create_topics:57 - Error while creeating topic topic_iot_sensors: KafkaError{code=TOPIC_ALREADY_EXISTS,val=36,str="Topic 'topic_iot_sensors' already exists."}

# %% [markdown]
# # Produce client data events

# %%
generator.produce_client_events(100)
# Out:
# %4|1746725246.121|CONFWARN|ccloud-python-client-364962d7-f8b2-4e17-afa9-91c51a1de59c#producer-3| [thrd:app]: Configuration property session.timeout.ms is a consumer property and will be ignored by this producer instance
# 2025-05-08 19:27:28.067 | INFO     | __main__:produce_client_events:96 - Message 1 sent
# %6|1746725248.067|GETSUBSCRIPTIONS|ccloud-python-client-364962d7-f8b2-4e17-afa9-91c51a1de59c#producer-3| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to WoMBUdMVTfqI/Ct4qc5ZWQ
# 2025-05-08 19:27:29.636 | INFO     | __main__:produce_client_events:96 - Message 2 sent
# 2025-05-08 19:27:29.860 | INFO     | __main__:produce_client_events:96 - Message 3 sent
# 2025-05-08 19:27:30.111 | INFO     | __main__:produce_client_events:96 - Message 4 sent
# 2025-05-08 19:27:30.532 | INFO     | __main__:produce_client_events:96 - Message 5 sent
# 2025-05-08 19:27:31.979 | INFO     | __main__:produce_client_events:96 - Message 6 sent
# 2025-05-08 19:27:32.572 | INFO     | __main__:produce_client_events:96 - Message 7 sent
# 2025-05-08 19:27:32.902 | INFO     | __main__:produce_client_events:96 - Message 8 sent
# 2025-05-08 19:27:33.950 | INFO     | __main__:produce_client_events:96 - Message 9 sent
# 2025-05-08 19:27:34.572 | INFO     | __main__:produce_client_events:96 - Message 10 sent
# 2025-05-08 19:27:35.547 | INFO     | __main__:produce_client_events:96 - Message 11 sent
# 2025-05-08 19:27:36.151 | INFO     | __main__:produce_client_events:96 - Message 12 sent
# 2025-05-08 19:27:36.990 | INFO     | __main__:produce_client_events:96 - Message 13 sent
# 2025-05-08 19:27:37.974 | INFO     | __main__:produce_client_events:96 - Message 14 sent
# 2025-05-08 19:27:38.248 | INFO     | __main__:produce_client_events:96 - Message 15 sent
# 2025-05-08 19:27:38.464 | INFO     | __main__:produce_client_events:96 - Message 16 sent
# 2025-05-08 19:27:39.072 | INFO     | __main__:produce_client_events:96 - Message 17 sent
# 2025-05-08 19:27:39.333 | INFO     | __main__:produce_client_events:96 - Message 18 sent
# 2025-05-08 19:27:39.834 | INFO     | __main__:produce_client_events:96 - Message 19 sent
# 2025-05-08 19:27:40.864 | INFO     | __main__:produce_client_events:96 - Message 20 sent
# 2025-05-08 19:27:41.826 | INFO     | __main__:produce_client_events:96 - Message 21 sent
# 2025-05-08 19:27:42.624 | INFO     | __main__:produce_client_events:96 - Message 22 sent
# 2025-05-08 19:27:43.146 | INFO     | __main__:produce_client_events:96 - Message 23 sent
# 2025-05-08 19:27:43.390 | INFO     | __main__:produce_client_events:96 - Message 24 sent
# 2025-05-08 19:27:43.907 | INFO     | __main__:produce_client_events:96 - Message 25 sent
# 2025-05-08 19:27:44.692 | INFO     | __main__:produce_client_events:96 - Message 26 sent
# 2025-05-08 19:27:45.794 | INFO     | __main__:produce_client_events:96 - Message 27 sent
# 2025-05-08 19:27:46.834 | INFO     | __main__:produce_client_events:96 - Message 28 sent
# 2025-05-08 19:27:47.053 | INFO     | __main__:produce_client_events:96 - Message 29 sent
# 2025-05-08 19:27:47.984 | INFO     | __main__:produce_client_events:96 - Message 30 sent
# 2025-05-08 19:27:49.148 | INFO     | __main__:produce_client_events:96 - Message 31 sent
# 2025-05-08 19:27:49.489 | INFO     | __main__:produce_client_events:96 - Message 32 sent
# 2025-05-08 19:27:50.343 | INFO     | __main__:produce_client_events:96 - Message 33 sent
# 2025-05-08 19:27:50.761 | INFO     | __main__:produce_client_events:96 - Message 34 sent
# 2025-05-08 19:27:51.355 | INFO     | __main__:produce_client_events:96 - Message 35 sent
# 2025-05-08 19:27:52.124 | INFO     | __main__:produce_client_events:96 - Message 36 sent
# 2025-05-08 19:27:52.824 | INFO     | __main__:produce_client_events:96 - Message 37 sent
# 2025-05-08 19:27:52.959 | INFO     | __main__:produce_client_events:96 - Message 38 sent
# 2025-05-08 19:27:53.466 | INFO     | __main__:produce_client_events:96 - Message 39 sent
# 2025-05-08 19:27:54.563 | INFO     | __main__:produce_client_events:96 - Message 40 sent
# 2025-05-08 19:27:55.212 | INFO     | __main__:produce_client_events:96 - Message 41 sent
# 2025-05-08 19:27:56.296 | INFO     | __main__:produce_client_events:96 - Message 42 sent
# 2025-05-08 19:27:56.672 | INFO     | __main__:produce_client_events:96 - Message 43 sent
# 2025-05-08 19:27:57.537 | INFO     | __main__:produce_client_events:96 - Message 44 sent
# 2025-05-08 19:27:57.878 | INFO     | __main__:produce_client_events:96 - Message 45 sent
# 2025-05-08 19:27:58.282 | INFO     | __main__:produce_client_events:96 - Message 46 sent
# 2025-05-08 19:27:58.489 | INFO     | __main__:produce_client_events:96 - Message 47 sent
# 2025-05-08 19:27:58.691 | INFO     | __main__:produce_client_events:96 - Message 48 sent
# 2025-05-08 19:27:59.655 | INFO     | __main__:produce_client_events:96 - Message 49 sent
# 2025-05-08 19:28:00.422 | INFO     | __main__:produce_client_events:96 - Message 50 sent
# 2025-05-08 19:28:01.052 | INFO     | __main__:produce_client_events:96 - Message 51 sent
# 2025-05-08 19:28:01.541 | INFO     | __main__:produce_client_events:96 - Message 52 sent
# 2025-05-08 19:28:01.834 | INFO     | __main__:produce_client_events:96 - Message 53 sent
# 2025-05-08 19:28:02.486 | INFO     | __main__:produce_client_events:96 - Message 54 sent
# 2025-05-08 19:28:03.470 | INFO     | __main__:produce_client_events:96 - Message 55 sent
# 2025-05-08 19:28:04.118 | INFO     | __main__:produce_client_events:96 - Message 56 sent
# 2025-05-08 19:28:04.644 | INFO     | __main__:produce_client_events:96 - Message 57 sent
# 2025-05-08 19:28:05.213 | INFO     | __main__:produce_client_events:96 - Message 58 sent
# 2025-05-08 19:28:05.407 | INFO     | __main__:produce_client_events:96 - Message 59 sent
# 2025-05-08 19:28:06.208 | INFO     | __main__:produce_client_events:96 - Message 60 sent
# 2025-05-08 19:28:06.560 | INFO     | __main__:produce_client_events:96 - Message 61 sent
# 2025-05-08 19:28:06.699 | INFO     | __main__:produce_client_events:96 - Message 62 sent
# 2025-05-08 19:28:07.607 | INFO     | __main__:produce_client_events:96 - Message 63 sent
# 2025-05-08 19:28:08.127 | INFO     | __main__:produce_client_events:96 - Message 64 sent
# 2025-05-08 19:28:08.687 | INFO     | __main__:produce_client_events:96 - Message 65 sent
# 2025-05-08 19:28:09.184 | INFO     | __main__:produce_client_events:96 - Message 66 sent
# 2025-05-08 19:28:09.420 | INFO     | __main__:produce_client_events:96 - Message 67 sent
# 2025-05-08 19:28:09.746 | INFO     | __main__:produce_client_events:96 - Message 68 sent
# 2025-05-08 19:28:10.759 | INFO     | __main__:produce_client_events:96 - Message 69 sent
# 2025-05-08 19:28:10.935 | INFO     | __main__:produce_client_events:96 - Message 70 sent
# 2025-05-08 19:28:11.169 | INFO     | __main__:produce_client_events:96 - Message 71 sent
# 2025-05-08 19:28:12.102 | INFO     | __main__:produce_client_events:96 - Message 72 sent
# 2025-05-08 19:28:12.328 | INFO     | __main__:produce_client_events:96 - Message 73 sent
# 2025-05-08 19:28:13.116 | INFO     | __main__:produce_client_events:96 - Message 74 sent
# 2025-05-08 19:28:13.900 | INFO     | __main__:produce_client_events:96 - Message 75 sent
# 2025-05-08 19:28:14.424 | INFO     | __main__:produce_client_events:96 - Message 76 sent
# 2025-05-08 19:28:15.524 | INFO     | __main__:produce_client_events:96 - Message 77 sent
# 2025-05-08 19:28:16.002 | INFO     | __main__:produce_client_events:96 - Message 78 sent
# 2025-05-08 19:28:17.045 | INFO     | __main__:produce_client_events:96 - Message 79 sent
# 2025-05-08 19:28:17.362 | INFO     | __main__:produce_client_events:96 - Message 80 sent
# 2025-05-08 19:28:17.991 | INFO     | __main__:produce_client_events:96 - Message 81 sent
# 2025-05-08 19:28:18.836 | INFO     | __main__:produce_client_events:96 - Message 82 sent
# 2025-05-08 19:28:19.947 | INFO     | __main__:produce_client_events:96 - Message 83 sent
# 2025-05-08 19:28:20.216 | INFO     | __main__:produce_client_events:96 - Message 84 sent
# 2025-05-08 19:28:20.879 | INFO     | __main__:produce_client_events:96 - Message 85 sent
# 2025-05-08 19:28:21.263 | INFO     | __main__:produce_client_events:96 - Message 86 sent
# 2025-05-08 19:28:22.020 | INFO     | __main__:produce_client_events:96 - Message 87 sent
# 2025-05-08 19:28:23.032 | INFO     | __main__:produce_client_events:96 - Message 88 sent
# 2025-05-08 19:28:23.899 | INFO     | __main__:produce_client_events:96 - Message 89 sent
# 2025-05-08 19:28:24.793 | INFO     | __main__:produce_client_events:96 - Message 90 sent
# 2025-05-08 19:28:25.129 | INFO     | __main__:produce_client_events:96 - Message 91 sent
# 2025-05-08 19:28:25.629 | INFO     | __main__:produce_client_events:96 - Message 92 sent
# 2025-05-08 19:28:26.724 | INFO     | __main__:produce_client_events:96 - Message 93 sent
# 2025-05-08 19:28:27.591 | INFO     | __main__:produce_client_events:96 - Message 94 sent
# 2025-05-08 19:28:27.948 | INFO     | __main__:produce_client_events:96 - Message 95 sent
# 2025-05-08 19:28:28.267 | INFO     | __main__:produce_client_events:96 - Message 96 sent
# 2025-05-08 19:28:28.585 | INFO     | __main__:produce_client_events:96 - Message 97 sent
# 2025-05-08 19:28:29.651 | INFO     | __main__:produce_client_events:96 - Message 98 sent
# 2025-05-08 19:28:30.585 | INFO     | __main__:produce_client_events:96 - Message 99 sent
# 2025-05-08 19:28:30.838 | INFO     | __main__:produce_client_events:96 - Message 100 sent

# %% [markdown]
# # Produce IOT events

# %%
generator.produce_iot_events(100)
# Out:
# %4|1746725333.912|CONFWARN|ccloud-python-client-364962d7-f8b2-4e17-afa9-91c51a1de59c#producer-4| [thrd:app]: Configuration property session.timeout.ms is a consumer property and will be ignored by this producer instance
# 2025-05-08 19:28:55.752 | INFO     | __main__:produce_iot_events:141 - Message 1 sent
# %6|1746725335.751|GETSUBSCRIPTIONS|ccloud-python-client-364962d7-f8b2-4e17-afa9-91c51a1de59c#producer-4| [thrd:main]: Telemetry client instance id changed from AAAAAAAAAAAAAAAAAAAAAA to g7V//9PdSnSdryL6igycAA
# 2025-05-08 19:28:56.935 | INFO     | __main__:produce_iot_events:141 - Message 2 sent
# 2025-05-08 19:28:58.467 | INFO     | __main__:produce_iot_events:141 - Message 3 sent
# 2025-05-08 19:28:58.885 | INFO     | __main__:produce_iot_events:141 - Message 4 sent
# 2025-05-08 19:28:59.226 | INFO     | __main__:produce_iot_events:141 - Message 5 sent
# 2025-05-08 19:28:59.411 | INFO     | __main__:produce_iot_events:141 - Message 6 sent
# 2025-05-08 19:29:00.212 | INFO     | __main__:produce_iot_events:141 - Message 7 sent
# 2025-05-08 19:29:00.458 | INFO     | __main__:produce_iot_events:141 - Message 8 sent
# 2025-05-08 19:29:01.501 | INFO     | __main__:produce_iot_events:141 - Message 9 sent
# 2025-05-08 19:29:02.290 | INFO     | __main__:produce_iot_events:141 - Message 10 sent
# 2025-05-08 19:29:02.768 | INFO     | __main__:produce_iot_events:141 - Message 11 sent
# 2025-05-08 19:29:03.435 | INFO     | __main__:produce_iot_events:141 - Message 12 sent
# 2025-05-08 19:29:03.937 | INFO     | __main__:produce_iot_events:141 - Message 13 sent
# 2025-05-08 19:29:04.656 | INFO     | __main__:produce_iot_events:141 - Message 14 sent
# 2025-05-08 19:29:05.279 | INFO     | __main__:produce_iot_events:141 - Message 15 sent
# 2025-05-08 19:29:05.695 | INFO     | __main__:produce_iot_events:141 - Message 16 sent
# 2025-05-08 19:29:06.059 | INFO     | __main__:produce_iot_events:141 - Message 17 sent
# 2025-05-08 19:29:06.649 | INFO     | __main__:produce_iot_events:141 - Message 18 sent
# 2025-05-08 19:29:06.923 | INFO     | __main__:produce_iot_events:141 - Message 19 sent
# 2025-05-08 19:29:07.919 | INFO     | __main__:produce_iot_events:141 - Message 20 sent
# 2025-05-08 19:29:08.175 | INFO     | __main__:produce_iot_events:141 - Message 21 sent
# 2025-05-08 19:29:08.997 | INFO     | __main__:produce_iot_events:141 - Message 22 sent
# 2025-05-08 19:29:09.774 | INFO     | __main__:produce_iot_events:141 - Message 23 sent
# 2025-05-08 19:29:10.816 | INFO     | __main__:produce_iot_events:141 - Message 24 sent
# 2025-05-08 19:29:11.468 | INFO     | __main__:produce_iot_events:141 - Message 25 sent
# 2025-05-08 19:29:12.223 | INFO     | __main__:produce_iot_events:141 - Message 26 sent
# 2025-05-08 19:29:13.035 | INFO     | __main__:produce_iot_events:141 - Message 27 sent
# 2025-05-08 19:29:13.565 | INFO     | __main__:produce_iot_events:141 - Message 28 sent
# 2025-05-08 19:29:14.715 | INFO     | __main__:produce_iot_events:141 - Message 29 sent
# 2025-05-08 19:29:15.793 | INFO     | __main__:produce_iot_events:141 - Message 30 sent
# 2025-05-08 19:29:16.711 | INFO     | __main__:produce_iot_events:141 - Message 31 sent
# 2025-05-08 19:29:17.375 | INFO     | __main__:produce_iot_events:141 - Message 32 sent
# 2025-05-08 19:29:17.759 | INFO     | __main__:produce_iot_events:141 - Message 33 sent
# 2025-05-08 19:29:18.659 | INFO     | __main__:produce_iot_events:141 - Message 34 sent
# 2025-05-08 19:29:19.429 | INFO     | __main__:produce_iot_events:141 - Message 35 sent
# 2025-05-08 19:29:19.652 | INFO     | __main__:produce_iot_events:141 - Message 36 sent
# 2025-05-08 19:29:20.263 | INFO     | __main__:produce_iot_events:141 - Message 37 sent
# 2025-05-08 19:29:21.218 | INFO     | __main__:produce_iot_events:141 - Message 38 sent
# 2025-05-08 19:29:21.714 | INFO     | __main__:produce_iot_events:141 - Message 39 sent
# 2025-05-08 19:29:22.577 | INFO     | __main__:produce_iot_events:141 - Message 40 sent
# 2025-05-08 19:29:23.002 | INFO     | __main__:produce_iot_events:141 - Message 41 sent
# 2025-05-08 19:29:23.834 | INFO     | __main__:produce_iot_events:141 - Message 42 sent
# 2025-05-08 19:29:24.904 | INFO     | __main__:produce_iot_events:141 - Message 43 sent
# 2025-05-08 19:29:25.823 | INFO     | __main__:produce_iot_events:141 - Message 44 sent
# 2025-05-08 19:29:26.767 | INFO     | __main__:produce_iot_events:141 - Message 45 sent
# 2025-05-08 19:29:27.197 | INFO     | __main__:produce_iot_events:141 - Message 46 sent
# 2025-05-08 19:29:27.927 | INFO     | __main__:produce_iot_events:141 - Message 47 sent
# 2025-05-08 19:29:28.764 | INFO     | __main__:produce_iot_events:141 - Message 48 sent
# 2025-05-08 19:29:29.559 | INFO     | __main__:produce_iot_events:141 - Message 49 sent
# 2025-05-08 19:29:30.619 | INFO     | __main__:produce_iot_events:141 - Message 50 sent
# 2025-05-08 19:29:31.492 | INFO     | __main__:produce_iot_events:141 - Message 51 sent
# 2025-05-08 19:29:32.317 | INFO     | __main__:produce_iot_events:141 - Message 52 sent
# 2025-05-08 19:29:33.487 | INFO     | __main__:produce_iot_events:141 - Message 53 sent
# 2025-05-08 19:29:34.395 | INFO     | __main__:produce_iot_events:141 - Message 54 sent
# 2025-05-08 19:29:34.894 | INFO     | __main__:produce_iot_events:141 - Message 55 sent
# 2025-05-08 19:29:35.254 | INFO     | __main__:produce_iot_events:141 - Message 56 sent
# 2025-05-08 19:29:36.232 | INFO     | __main__:produce_iot_events:141 - Message 57 sent
# 2025-05-08 19:29:37.309 | INFO     | __main__:produce_iot_events:141 - Message 58 sent
# 2025-05-08 19:29:37.784 | INFO     | __main__:produce_iot_events:141 - Message 59 sent
# 2025-05-08 19:29:38.444 | INFO     | __main__:produce_iot_events:141 - Message 60 sent
# 2025-05-08 19:29:38.960 | INFO     | __main__:produce_iot_events:141 - Message 61 sent
# 2025-05-08 19:29:39.779 | INFO     | __main__:produce_iot_events:141 - Message 62 sent
# 2025-05-08 19:29:40.317 | INFO     | __main__:produce_iot_events:141 - Message 63 sent
# 2025-05-08 19:29:40.982 | INFO     | __main__:produce_iot_events:141 - Message 64 sent
# 2025-05-08 19:29:41.738 | INFO     | __main__:produce_iot_events:141 - Message 65 sent
# 2025-05-08 19:29:42.523 | INFO     | __main__:produce_iot_events:141 - Message 66 sent
# 2025-05-08 19:29:43.166 | INFO     | __main__:produce_iot_events:141 - Message 67 sent
# 2025-05-08 19:29:44.077 | INFO     | __main__:produce_iot_events:141 - Message 68 sent
# 2025-05-08 19:29:44.618 | INFO     | __main__:produce_iot_events:141 - Message 69 sent
# 2025-05-08 19:29:45.125 | INFO     | __main__:produce_iot_events:141 - Message 70 sent
# 2025-05-08 19:29:45.692 | INFO     | __main__:produce_iot_events:141 - Message 71 sent
# 2025-05-08 19:29:45.884 | INFO     | __main__:produce_iot_events:141 - Message 72 sent
# 2025-05-08 19:29:46.004 | INFO     | __main__:produce_iot_events:141 - Message 73 sent
# 2025-05-08 19:29:46.174 | INFO     | __main__:produce_iot_events:141 - Message 74 sent
# 2025-05-08 19:29:47.222 | INFO     | __main__:produce_iot_events:141 - Message 75 sent
# 2025-05-08 19:29:47.869 | INFO     | __main__:produce_iot_events:141 - Message 76 sent
# 2025-05-08 19:29:48.402 | INFO     | __main__:produce_iot_events:141 - Message 77 sent
# 2025-05-08 19:29:48.822 | INFO     | __main__:produce_iot_events:141 - Message 78 sent
# 2025-05-08 19:29:49.581 | INFO     | __main__:produce_iot_events:141 - Message 79 sent
# 2025-05-08 19:29:49.958 | INFO     | __main__:produce_iot_events:141 - Message 80 sent
# 2025-05-08 19:29:50.673 | INFO     | __main__:produce_iot_events:141 - Message 81 sent
# 2025-05-08 19:29:51.140 | INFO     | __main__:produce_iot_events:141 - Message 82 sent
# 2025-05-08 19:29:52.177 | INFO     | __main__:produce_iot_events:141 - Message 83 sent
# 2025-05-08 19:29:52.654 | INFO     | __main__:produce_iot_events:141 - Message 84 sent
# 2025-05-08 19:29:53.002 | INFO     | __main__:produce_iot_events:141 - Message 85 sent
# 2025-05-08 19:29:53.691 | INFO     | __main__:produce_iot_events:141 - Message 86 sent
# 2025-05-08 19:29:53.930 | INFO     | __main__:produce_iot_events:141 - Message 87 sent
# 2025-05-08 19:29:54.339 | INFO     | __main__:produce_iot_events:141 - Message 88 sent
# 2025-05-08 19:29:55.107 | INFO     | __main__:produce_iot_events:141 - Message 89 sent
# 2025-05-08 19:29:55.292 | INFO     | __main__:produce_iot_events:141 - Message 90 sent
# 2025-05-08 19:29:55.819 | INFO     | __main__:produce_iot_events:141 - Message 91 sent
# 2025-05-08 19:29:56.725 | INFO     | __main__:produce_iot_events:141 - Message 92 sent
# 2025-05-08 19:29:57.076 | INFO     | __main__:produce_iot_events:141 - Message 93 sent
# 2025-05-08 19:29:58.124 | INFO     | __main__:produce_iot_events:141 - Message 94 sent
# 2025-05-08 19:29:58.891 | INFO     | __main__:produce_iot_events:141 - Message 95 sent
# 2025-05-08 19:29:59.173 | INFO     | __main__:produce_iot_events:141 - Message 96 sent
# 2025-05-08 19:29:59.571 | INFO     | __main__:produce_iot_events:141 - Message 97 sent
# 2025-05-08 19:30:00.457 | INFO     | __main__:produce_iot_events:141 - Message 98 sent
# 2025-05-08 19:30:01.012 | INFO     | __main__:produce_iot_events:141 - Message 99 sent
# 2025-05-08 19:30:01.462 | INFO     | __main__:produce_iot_events:141 - Message 100 sent
